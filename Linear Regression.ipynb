# %%
#a) membuat plot scatter
import matplotlib.pyplot as plt
x=[45.4,3.1,11.8,8.5,1.2,4.6,151.3,45.6,13.5,10.5,12.7,56.0,1.6,2.0,14.0,7.9,14.8,40.8,16.2,37.2,14.8,8.9,64.7,11.2,15.2,10.0,
   41.3,19.3,18.0,3.8,9.0,4.0,4.0,1.7,29.6,132.0,93.4,2.7,15.0,1.4,142.2,29.1,4.7,14.1,33.7,32.6,4.4,59.3,119.3,45.4] #luas lahan
y=[8579,2046,3188,627,407,3036,35389,10802,3026,2771,3219,8213,618,256,1344,1736,2176,22848,3053,7079,3741,2075,15277,2960,1457,3010,7455,
   5307,11374,783,4282,2155,800,515,7281,31155,17801,579,3076,280,25605,7960,1798,3212,10216,10532,3600,20129,33472,9455] #jumlah pohon
plt.scatter(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True, which='both')
plt.show()

# %%
#d) menggambar garis regresi y saat x=80
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

x =[[45.4],[3.1],[11.8],[8.5],[1.2],[4.6],[151.3],[45.6],[13.5],[10.5],[12.7],[56.0],[1.6],[2.0],[14.0],[7.9],[14.8],[40.8],[16.2],[37.2],
    [14.8],[8.9],[64.7],[11.2],[15.2],[10.0],[41.3],[19.3],[18.0],[3.8],[9.0],[4.0],[4.0],[1.7],[29.6],[132.0],[93.4],[2.7],[15.0],[1.4],
    [142.2],[29.1],[4.7],[14.1],[33.7],[32.6],[4.4],[59.3],[119.3],[45.4]] #luas lahan
y =[[8579],[2046],[3188],[627],[407],[3036],[35389],[10802],[3026],[2771],[3219],[8213],[618],[256],[1344],[1736],[2176],[22848],[3053],
    [7079],[3741],[2075],[15277],[2960],[1457],[3010],[7455],[5307],[11374],[783],[4282],[2155],[800],[515],[7281],[31155],[17801],[579],
    [3076],[280],[25605],[7960],[1798],[3212],[10216],[10532],[3600],[20129],[33472],[9455]] #Jumlah pohon

model = LinearRegression()
model.fit(x,y)
y_predict= model.predict(x)

plt.figure()
plt.plot (x, y, 'g.')
plt.axis([0.9, 170, 200, 35400])
plt.xlabel('luas lahan')
plt.ylabel('jumlah pohon')
plt.grid (True)
plt.plot(x, y_predict, color = 'pink')
plt.show()

jp_predict = model.predict ([[80]])
print ('Jika luas lahan 80 maka jumlah pohon adl : ', jp_predict)
# Out:
# Jika luas lahan 80 maka jumlah pohon adl :  [[18618.18366501]]

# %%
#Plot Polinomial berderajat 2
import numpy
import matplotlib.pyplot as plt

x=[45.4,3.1,11.8,8.5,1.2,4.6,151.3,45.6,13.5,10.5,12.7,56.0,1.6,2.0,14.0,7.9,14.8,40.8,16.2,37.2,14.8,8.9,64.7,11.2,15.2,10.0,
   41.3,19.3,18.0,3.8,9.0,4.0,4.0,1.7,29.6,132.0,93.4,2.7,15.0,1.4,142.2,29.1,4.7,14.1,33.7,32.6,4.4,59.3,119.3,45.4] #luas lahan
y=[8579,2046,3188,627,407,3036,35389,10802,3026,2771,3219,8213,618,256,1344,1736,2176,22848,3053,7079,3741,2075,15277,2960,1457,3010,7455,
   5307,11374,783,4282,2155,800,515,7281,31155,17801,579,3076,280,25605,7960,1798,3212,10216,10532,3600,20129,33472,9455] #jumlah pohon

mymodel=numpy.poly1d(numpy.polyfit(x,y,2))
myline=numpy.linspace(1.0,152.0,35400)

plt.scatter(x,y, color='green')
plt.xlabel('luas lahan (ha)')
plt.ylabel('jumlah pohon (phn)')
plt.grid (True)
plt.title('Hubungan luas lahan dengan jumlah pohon')
plt.plot(myline, mymodel(myline), color='pink')
plt.show()

# %%
#Plot Polinomial berderajat 3
import numpy
import matplotlib.pyplot as plt

xx=[45.4,3.1,11.8,8.5,1.2,4.6,151.3,45.6,13.5,10.5,12.7,56.0,1.6,2.0,14.0,7.9,14.8,40.8,16.2,37.2,14.8,8.9,64.7,11.2,15.2,10.0,
   41.3,19.3,18.0,3.8,9.0,4.0,4.0,1.7,29.6,132.0,93.4,2.7,15.0,1.4,142.2,29.1,4.7,14.1,33.7,32.6,4.4,59.3,119.3,45.4] #luas lahan
y=[8579,2046,3188,627,407,3036,35389,10802,3026,2771,3219,8213,618,256,1344,1736,2176,22848,3053,7079,3741,2075,15277,2960,1457,3010,7455,
   5307,11374,783,4282,2155,800,515,7281,31155,17801,579,3076,280,25605,7960,1798,3212,10216,10532,3600,20129,33472,9455] #jumlah pohon

mymodel=numpy.poly1d(numpy.polyfit(x,y,3))
myline=numpy.linspace(1.0,152.0,35400)

plt.scatter(x,y, color='green')
plt.xlabel('luas lahan (ha)')
plt.ylabel('jumlah pohon (phn)')
plt.grid (True)
plt.title('Hubungan luas lahan dengan jumlah pohon')
plt.plot(myline, mymodel(myline), color='pink')
plt.show()

# %%
#f) Plot Polinomial berderajat 3, jika x=80 maka nilai y?
import numpy
import matplotlib.pyplot as plt

x=[45.4,3.1,11.8,8.5,1.2,4.6,151.3,45.6,13.5,10.5,12.7,56.0,1.6,2.0,14.0,7.9,14.8,40.8,16.2,37.2,14.8,8.9,64.7,11.2,15.2,10.0,
   41.3,19.3,18.0,3.8,9.0,4.0,4.0,1.7,29.6,132.0,93.4,2.7,15.0,1.4,142.2,29.1,4.7,14.1,33.7,32.6,4.4,59.3,119.3,45.4] #luas lahan
y=[8579,2046,3188,627,407,3036,35389,10802,3026,2771,3219,8213,618,256,1344,1736,2176,22848,3053,7079,3741,2075,15277,2960,1457,3010,7455,
   5307,11374,783,4282,2155,800,515,7281,31155,17801,579,3076,280,25605,7960,1798,3212,10216,10532,3600,20129,33472,9455] #jumlah pohon

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))
myline = numpy.linspace (1.0, 152.0, 35000)
x_pred = 80
y_pred = mymodel(x_pred)
print("Jumlah Pohon saat x=80:" , y_pred)
# Plot data asli
plt.scatter(x, y, label='Data Asli')
# Buat titik-titik pada kurva regresi polinomial
x_curve = numpy.linspace(1.0, 152.0, 35000) 
y_curve = mymodel(x_curve)
# Plot kurva regresi polinomial
plt.plot(x_curve, y_curve, color='green', label='Regresi Polinomial (Derajat 2)')
# Tandai titik prediksi
plt.scatter(x_pred, y_pred, color='red', label='Prediksi (x=80)')
plt.xlabel('Luas Sadapan(ha)')
plt.ylabel('Jumlah Pohon')
plt.legend()
plt.show()
# Out:
# Jumlah Pohon saat x=80: 19410.358959075584

# %%
#Plot Polinomial berderajat 3, jika x=80 maka nilai y?
import numpy
import matplotlib.pyplot as plt

x=[45.4,3.1,11.8,8.5,1.2,4.6,151.3,45.6,13.5,10.5,12.7,56.0,1.6,2.0,14.0,7.9,14.8,40.8,16.2,37.2,14.8,8.9,64.7,11.2,15.2,10.0,
   41.3,19.3,18.0,3.8,9.0,4.0,4.0,1.7,29.6,132.0,93.4,2.7,15.0,1.4,142.2,29.1,4.7,14.1,33.7,32.6,4.4,59.3,119.3,45.4] #luas lahan
y=[8579,2046,3188,627,407,3036,35389,10802,3026,2771,3219,8213,618,256,1344,1736,2176,22848,3053,7079,3741,2075,15277,2960,1457,3010,7455,
   5307,11374,783,4282,2155,800,515,7281,31155,17801,579,3076,280,25605,7960,1798,3212,10216,10532,3600,20129,33472,9455] #jumlah pohon

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))
myline = numpy.linspace (1.0, 152.0, 35000)
x_pred = 80
y_pred = mymodel(x_pred)
print("Jumlah Pohon saat x=80:" , y_pred)
# Plot data asli
plt.scatter(x, y, label='Data Asli')
# Buat titik-titik pada kurva regresi polinomial
x_curve = numpy.linspace(1.0, 152.0, 35000) 
y_curve = mymodel(x_curve)
# Plot kurva regresi polinomial
plt.plot(x_curve, y_curve, color='green', label='Regresi Polinomial (Derajat 3)')
# Tandai titik prediksi
plt.scatter(x_pred, y_pred, color='red', label='Prediksi (x=80)')
plt.xlabel('Luas Sadapan(ha)')
plt.ylabel('Jumlah Pohon')
plt.legend()
plt.show()
# Out:
# Jumlah Pohon saat x=80: 19410.358959075584

# %%
#Nilai median, mean, modus, Q1, Q2, Q3, varian populasi, varian sample dari x

import numpy as np
x=[45.4,3.1,11.8,8.5,1.2,4.6,151.3,45.6,13.5,10.5,12.7,56.0,1.6,2.0,14.0,7.9,14.8,40.8,16.2,37.2,14.8,8.9,64.7,11.2,15.2,10.0,
   41.3,19.3,18.0,3.8,9.0,4.0,4.0,1.7,29.6,132.0,93.4,2.7,15.0,1.4,142.2,29.1,4.7,14.1,33.7,32.6,4.4,59.3,119.3,45.4] #luas lahan

rata2=np.mean(x)
print('rata-rata :', rata2)
median=np.median(x)
print('median :', median)
print ('Q1 : ', np.quantile(x, 0.25))
print ('Q2 : ', np.quantile(x, 0.50))
print ('Q3 : ', np.quantile(x, 0.75))
import statistics as sts
m=sts.multimode(x)
print('modus :', m)
vp= sts.pvariance(x)
print('varian populasi=', vp)
vs=sts.variance(x)
print('varian sampel= ', vs)
# Out:
# rata-rata : 29.67
# median : 14.45
# Q1 :  5.5
# Q2 :  14.45
# Q3 :  39.9
# modus : [45.4, 14.8, 4.0]
# varian populasi= 1373.8597
# varian sampel=  1401.8976530612244

# %%
#b) menggambar garis regresi
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

x =[[45.4],[3.1],[11.8],[8.5],[1.2],[4.6],[151.3],[45.6],[13.5],[10.5],[12.7],[56.0],[1.6],[2.0],[14.0],[7.9],[14.8],[40.8],[16.2],[37.2],
    [14.8],[8.9],[64.7],[11.2],[15.2],[10.0],[41.3],[19.3],[18.0],[3.8],[9.0],[4.0],[4.0],[1.7],[29.6],[132.0],[93.4],[2.7],[15.0],[1.4],
    [142.2],[29.1],[4.7],[14.1],[33.7],[32.6],[4.4],[59.3],[119.3],[45.4]] #luas lahan
y =[[8579],[2046],[3188],[627],[407],[3036],[35389],[10802],[3026],[2771],[3219],[8213],[618],[256],[1344],[1736],[2176],[22848],[3053],
    [7079],[3741],[2075],[15277],[2960],[1457],[3010],[7455],[5307],[11374],[783],[4282],[2155],[800],[515],[7281],[31155],[17801],[579],
    [3076],[280],[25605],[7960],[1798],[3212],[10216],[10532],[3600],[20129],[33472],[9455]] #Jumlah pohon

model = LinearRegression()
model.fit(x,y)
y_predict= model.predict(x)

plt.figure()
plt.plot (x, y, 'g.')
plt.axis([0.9, 170, 200, 35000])
plt.xlabel('luas lahan')
plt.ylabel('jumlah pohon')
plt.grid (True)
plt.plot(x, y_predict, color = 'pink')
plt.show()

# %%
#Plot Polynomial berderajat 1
import numpy
import matplotlib.pyplot as plt

x=[45.4,3.1,11.8,8.5,1.2,4.6,151.3,45.6,13.5,10.5,12.7,56.0,1.6,2.0,14.0,7.9,14.8,40.8,16.2,37.2,14.8,8.9,64.7,11.2,15.2,10.0,
   41.3,19.3,18.0,3.8,9.0,4.0,4.0,1.7,29.6,132.0,93.4,2.7,15.0,1.4,142.2,29.1,4.7,14.1,33.7,32.6,4.4,59.3,119.3,45.4] #luas lahan
y=[8579,2046,3188,627,407,3036,35389,10802,3026,2771,3219,8213,618,256,1344,1736,2176,22848,3053,7079,3741,2075,15277,2960,1457,3010,7455,
   5307,11374,783,4282,2155,800,515,7281,31155,17801,579,3076,280,25605,7960,1798,3212,10216,10532,3600,20129,33472,9455] #jumlah pohon

mymodel=numpy.poly1d(numpy.polyfit(x,y,1))
myline=numpy.linspace(1.0,152.0,35400)

plt.scatter(x,y, color='green')
plt.xlabel('luas lahan (ha)')
plt.ylabel('jumlah pohon (phn)')
plt.grid (True)
plt.title('Hubungan luas lahan dengan jumlah pohon')
plt.plot(myline, mymodel(myline), color='pink')
plt.show()

# %%
import numpy as np
import statistics as sts
import pandas as pd
x =[[45.4],[3.1],[11.8],[8.5],[1.2],[4.6],[151.3],[45.6],[13.5],[10.5],[12.7],[56.0],[1.6],[2.0],[14.0],[7.9],[14.8],[40.8],[16.2],[37.2],[14.8],[8.9],[64.7],[11.2],[15.2],[10.0],[41.3],[19.3],[18.0],[3.8],[9.0],[4.0],[4.0],[1.7],[29.6],[132.0],[93.4],[2.7],[15.0],[1.4],[142.2],[29.1],[4.7],[14.1],[33.7],[32.6],[4.4],[59.3],[119.3],[45.4]] #luas lahan
y =[[8579],[2046],[3188],[627],[407],[3036],[35389],[10802],[3026],[2771],[3219],[8213],[618],[256],[1344],[1736],[2176],[22848],[3053],[7079],[3741],[2075],[15277],[2960],[1457],[3010],[7455],[5307],[11374],[783],[4282],[2155],[800],[515],[7281],[31155],[17801],[579],[3076],[280],[25605],[7960],[1798],[3212],[10216],[10532],[3600],[20129],[33472],[9455]] #Jumlah pohon

print(f'{"="*15} MENCARI RATA RATA X DAN Y SERTA KORELASI X DAN Y {"="*15}')
#mencari rata" x dan y
ratax = np.average(x)
ratay = np.average(y)
print(f'rata rata data x = {ratax}')
print(f'rata rata data y = {ratay}')

#menghitung Xi - Xbar
kumpulan = []
for i in x:
    kurang = i-ratax
    sementara = [kurang]
    kumpulan.extend(sementara)
print(f'nilai (xi-xbar) : {kumpulan}')
#diperoleh output kumpulan (xi-xbar)

#menghitung Yi - Ybar
kumpulan2 = []
for i in y:
    kurang = i-np.average(y)
    sementara = [kurang]
    kumpulan2.extend(sementara)
print(f'nilai (yi-ybar) : {kumpulan}')
#diperoleh output kumpulan2 (yi-ybar)
# Out:
# =============== MENCARI RATA RATA X DAN Y SERTA KORELASI X DAN Y ===============
# rata rata data x = 29.67
# rata rata data y = 7355.1
# nilai (xi-xbar) : [array([15.73]), array([-26.57]), array([-17.87]), array([-21.17]), array([-28.47]), array([-25.07]), array([121.63]), array([15.93]), array([-16.17]), array([-19.17]), array([-16.97]), array([26.33]), array([-28.07]), array([-27.67]), array([-15.67]), array([-21.77]), array([-14.87]), array([11.13]), array([-13.47]), array([7.53]), array([-14.87]), array([-20.77]), array([35.03]), array([-18.47]), array([-14.47]), array([-19.67]), array([11.63]), array([-10.37]), array([-11.67]), array([-25.87]), array([-20.67]), array([-25.67]), array([-25.67]), array([-27.97]), array([-0.07]), array([102.33]), array([63.73]), array([-26.97]), array([-14.67]), array([-28.27]), array([112.53]), array([-0.57]), array([-24.97]), array([-15.57]), array([4.03]), array([2.93]), array([-25.27]), array([29.63]), array([89.63]), array([15.73])]
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib import pyplot as plt

x =[[45.4],[3.1],[11.8],[8.5],[1.2],[4.6],[151.3],[45.6],[13.5],[10.5],[12.7],[56.0],[1.6],[2.0],[14.0],[7.9],[14.8],[40.8],[16.2],[37.2],[14.8],[8.9],[64.7],[11.2],[15.2],[10.0],[41.3],[19.3],[18.0],[3.8],[9.0],[4.0],[4.0],[1.7],[29.6],[132.0],[93.4],[2.7],[15.0],[1.4],[142.2],[29.1],[4.7],[14.1],[33.7],[32.6],[4.4],[59.3],[119.3],[45.4]] #luas lahan
y =[[8579],[2046],[3188],[627],[407],[3036],[35389],[10802],[3026],[2771],[3219],[8213],[618],[256],[1344],[1736],[2176],[22848],[3053],[7079],[3741],[2075],[15277],[2960],[1457],[3010],[7455],[5307],[11374],[783],[4282],[2155],[800],[515],[7281],[31155],[17801],[579],[3076],[280],[25605],[7960],[1798],[3212],[10216],[10532],[3600],[20129],[33472],[9455]] #Jumlah pohon

#nilai awal model
model = LinearRegression()
#sesuaikan data dengan model
model.fit(x, y)
#prediksi
y_predict = model.predict(x)

#evaluasi model
rmse = mean_squared_error(y, y_predict)
r2 = r2_score(y, y_predict)

#print nilai
print('Slope:' ,model.coef_)
print('Intercept:' , model.intercept_)
print('Root mean squared error:' , rmse)
print('R2 score:' , r2)

#nilai plotting
plt.scatter(x, y, s=5)
plt.xlabel('x')
plt.ylabel('y')

#nilai hasil prediksi
plt.plot(x, y_predict, color='r')
plt.show()
# Out:
# Slope: [[223.78469432]]
# Intercept: [715.40811959]
# Root mean squared error: 8865551.765822256
# R2 score: 0.8858530501887115
